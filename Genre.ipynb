# %%
# Dependencies

import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Import data from .txt file

with open('movie_data.txt') as json_file:
    data = json.load(json_file)

data['1999']['The Sixth Sense']['Genre']
# Out:
# 'Drama, Mystery, Thriller'

# %%
genres = {}
genre_list = []

for year in list(data.keys()):
    movies = list(data[year].keys())
    genre_list = []
    for movie in movies:
        try:
            genre = data[year][movie]['Genre'].split(', ')
            for i in genre:
                genre_list.append(i)
        except Exception as e:
            print(str(e)+" Year: "+year+" Movie: "+movie)
    genres[year] = genre_list
# Out:
# 'Genre' Year: 1980 Movie: In God We Trust (or Gimme That Prime Time Religion)
# 'Genre' Year: 1981 Movie: Indiana Jones and the Raiders of the Lost Ark
# 'Genre' Year: 1981 Movie: Cinderella1981 Re-release
# 'Genre' Year: 1982 Movie: Indiana Jones and the Raiders of the Lost Ark
# 'Genre' Year: 1982 Movie: Cinderella1981 Re-release
# 'Genre' Year: 1982 Movie: Bambi1982 Re-release
# 'Genre' Year: 1982 Movie: Indiana Jones and the Raiders of the Lost Ark1982 Re-release
# 'Genre' Year: 1983 Movie: Snow White and the Seven Dwarfs1983 Re-release
# 'Genre' Year: 1984 Movie: The Jungle Book1984 Re-release
# 'Genre' Year: 1985 Movie: E.T. the Extra-Terrestrial1985 Re-release
# 'Genre' Year: 1986 Movie: One Hundred and One Dalmatians1985 Re-release
# 'Genre' Year: 1987 Movie: Snow White and the Seven Dwarfs1987 Re-release
# 'Genre' Year: 1987 Movie: Cinderella1987 Re-release
# 'Genre' Year: 1988 Movie: Bambi1988 Re-release
# 'Genre' Year: 1988 Movie: The Fox and the Hound1988 Re-release
# 'Genre' Year: 1989 Movie: Peter Pan1989 Re-release
# 'Genre' Year: 1990 Movie: The Jungle Book1990 Re-release
# 'Genre' Year: 1991 Movie: One Hundred and One Dalmatians1991 Re-release
# 'Genre' Year: 1993 Movie: Snow White and the Seven Dwarfs1993 Re-release
# 'Genre' Year: 1997 Movie: Star Wars: Episode IV - A New Hope1997 Special Edition
# 'Genre' Year: 1997 Movie: Star Wars: Episode V - The Empire Strikes Back1997 Special Edition
# 'Genre' Year: 1997 Movie: Star Wars: Episode VI - Return of the Jedi1997 Special Edition
# 'Genre' Year: 1998 Movie: Ever After: A Cinderella Story
# 'Genre' Year: 1999 Movie: Pokémon: The First Movie - Mewtwo Strikes Back
# 'Genre' Year: 2003 Movie: X2: X-Men United
# 'Genre' Year: 2007 Movie: Fantastic 4: Rise of the Silver Surfer
# 'Genre' Year: 2007 Movie: Tyler Perry's Why Did I Get Married?
# 'Genre' Year: 2010 Movie: Knight and Day2010 Re-release
# 'Genre' Year: 2011 Movie: The Lion King2011 3D Release
# 'Genre' Year: 2013 Movie: Lee Daniels' The Butler
# 'Genre' Year: 2015 Movie: The Divergent Series: Insurgent
# 'Genre' Year: 2020 Movie: My Hero Academia: Heroes Rising
# 'Genre' Year: 2020 Movie: Weathering with You

# %%
genre_df = pd.DataFrame(data = genre_count, columns = [i])
for i in list(genres.keys()):
    genre_count = pd.Series(genres[i]).value_counts()
    genre_df[i] = genre_count
genre_df
# Out:
#            2020  1980  1981  1982  1983  1984  1985  1986  1987  1988  ...  \
# Drama        25  17.0  18.0  17.0  23.0  18.0  23.0  18.0  14.0  21.0  ...
# Action       18  10.0  10.0  11.0  11.0  17.0  14.0  11.0  13.0  11.0  ...
# Comedy       17  25.0  19.0  24.0  23.0  24.0  24.0  30.0  31.0  28.0  ...
# Adventure    13   6.0  10.0   8.0  11.0  13.0  17.0  11.0  10.0   7.0  ...
# Horror       10   6.0   9.0   5.0   5.0   2.0   3.0   4.0   4.0   2.0  ...
# Thriller      8   7.0  11.0   6.0   5.0   4.0   6.0   5.0  10.0   6.0  ...
# Mystery       7   2.0   4.0   3.0   1.0   2.0   4.0   NaN   1.0   1.0  ...
# Crime         7  11.0   8.0   5.0   8.0   6.0   7.0   5.0  11.0  14.0  ...
# Family        4   2.0   NaN   2.0   2.0   2.0   4.0   4.0   4.0   3.0  ...
# Fantasy       4   8.0   4.0   6.0   3.0   7.0   3.0   2.0   6.0   4.0  ...
# Biography     4   4.0   2.0   2.0   1.0   1.0   3.0   1.0   1.0   3.0  ...
# Sci-Fi        4   4.0   5.0   8.0   4.0   5.0   4.0   4.0   5.0   1.0  ...
# Animation     4   NaN   NaN   NaN   NaN   1.0   2.0   2.0   NaN   3.0  ...
# Romance       3   7.0   8.0   5.0  13.0  11.0   5.0  10.0   9.0   8.0  ...
# War           2   1.0   1.0   NaN   1.0   1.0   NaN   2.0   2.0   NaN  ...
# Short         1   1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# History       1   NaN   2.0   1.0   1.0   1.0   3.0   NaN   NaN   1.0  ...
# Music         1   7.0   1.0   2.0   3.0   6.0   1.0   1.0   2.0   NaN  ...
#
#            2010  2011  2012  2013  2014  2015  2016  2017  2018  2019
# Drama      13.0  14.0  17.0  11.0  14.0  14.0  12.0  14.0  13.0  16.0
# Action     22.0  16.0  23.0  17.0  27.0  20.0  24.0  25.0  22.0  22.0
# Comedy     19.0  22.0  19.0  17.0  20.0  23.0  21.0  20.0  19.0  20.0
# Adventure  22.0  21.0  28.0  23.0  26.0  25.0  30.0  23.0  24.0  28.0
# Horror      2.0   1.0   2.0   4.0   2.0   1.0   6.0   6.0   6.0   6.0
# Thriller    7.0   5.0  10.0  11.0   5.0   9.0   3.0   5.0   8.0   7.0
# Mystery     4.0   3.0   3.0   4.0   5.0   1.0   4.0   5.0   3.0   3.0
# Crime       5.0   4.0   4.0   7.0   6.0   4.0   5.0   6.0   4.0   4.0
# Family      6.0   4.0   3.0   2.0   4.0   6.0   6.0   3.0   7.0   5.0
# Fantasy     7.0   7.0   9.0   5.0   2.0   3.0   5.0   8.0   6.0   9.0
# Biography   2.0   2.0   2.0   2.0   3.0   4.0   2.0   1.0   3.0   3.0
# Sci-Fi      2.0   9.0   8.0   8.0  10.0   8.0   9.0   6.0  13.0   7.0
# Animation   8.0   9.0   7.0   9.0   9.0   8.0  11.0  10.0   7.0  10.0
# Romance     9.0   5.0   5.0   3.0   4.0   2.0   NaN   1.0   5.0   1.0
# War         NaN   NaN   NaN   NaN   1.0   NaN   1.0   NaN   NaN   1.0
# Short       1.0   NaN   NaN   1.0   NaN   NaN   NaN   NaN   NaN   NaN
# History     NaN   1.0   2.0   2.0   1.0   2.0   1.0   2.0   NaN   1.0
# Music       NaN   1.0   1.0   NaN   NaN   2.0   NaN   2.0   3.0   2.0
#
# [18 rows x 41 columns]

# %%
plt.plot(genre_df.loc['Drama']);
